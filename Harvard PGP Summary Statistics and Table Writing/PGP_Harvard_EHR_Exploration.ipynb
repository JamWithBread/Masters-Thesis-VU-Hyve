# %%
import pandas as pd
import os

# %% [markdown]
# # Build combined dataframes for each EHR table

# %%
ehr_table_names = ['Demographic Information', 'Conditions', 'Medications', 'Allergies', 'Procedures', 'Test Results', 'Immunizations']

# %%
def get_filepaths(all_data_directory):
    directory = all_data_directory
    paths = []
    for filename in os.listdir(directory):
        path = os.path.join(directory, filename)
        if os.path.isdir(path+"/ehrs"):
            paths.append(path+"/ehrs")
    return paths

# %%
def read_table(path):
    df = pd.read_csv(path, delimiter = '\t')
    return df

def transform_table_demographics(df):
    df = df.transpose()
    df = df.iloc[2:]
    df.columns = ['Date of Birth', 'Gender', 'Weight', 'Height', 'Blood Type', 'Race']
    df.reset_index(drop = True, inplace=True)

    return df

def transform_table_generic(df):
    df.drop(df.columns[0], axis = 1, inplace = True)
    return df

def get_col_names(df):
    #df = df.transpose()
    return df.columns

def add_profileID_col(df, path):
    profile_id = path[-13:-5]
    df.insert(0, 'profile_id', profile_id)
    return df

def process_table_type(ehr_dir_path, filename):
    filepath = os.path.join(ehr_dir_path, filename)

    if "Demographic" in filename:
        df = read_table(filepath)
        df = transform_table_demographics(df)
        df = add_profileID_col(df, ehr_dir_path)
        global demo_info
        demo_info = pd.concat([demo_info, df])
        first_column = demo_info.pop('profile_id')
        demo_info.insert(0, 'profile_id', first_column)
    
    elif 'Conditions' in filename:
        df = read_table(filepath)
        df = transform_table_generic(df)
        df = add_profileID_col(df, ehr_dir_path)
        global conditions
        conditions = pd.concat([df, conditions])
        
    elif 'Medications' in filename:
        df = read_table(filepath)
        df = transform_table_generic(df)
        df = add_profileID_col(df, ehr_dir_path)
        global medications
        medications = pd.concat([df, medications])
        
    elif 'Allergies' in filename:
        df = read_table(filepath)
        df = transform_table_generic(df)
        df = add_profileID_col(df, ehr_dir_path)
        global allergies
        allergies = pd.concat([df, allergies])
        
    elif 'Procedures' in filename:
        df = read_table(filepath)
        df = transform_table_generic(df)
        df = add_profileID_col(df, ehr_dir_path)
        global procedures
        procedures = pd.concat([df, procedures])
        
    elif 'Test Results' in filename:
        df = read_table(filepath)
        df = transform_table_generic(df)
        df = add_profileID_col(df, ehr_dir_path)
        global test_results
        test_results = pd.concat([df, test_results])
        
    elif 'Immunizations' in filename:
        df = read_table(filepath)
        df = transform_table_generic(df)
        df = add_profileID_col(df, ehr_dir_path)
        global immunizations
        immunizations = pd.concat([df, immunizations])
    
    else:
        pass
        
    return None

def get_txt_profiles(txt_path):
    df = pd.read_csv(txt_path, delimiter = '\t', header = None)
    profiles = df[0].values.tolist()
    return profiles

def remove_intersecting_profiles(paths, provider_id):
    _23andMe_profiles = '/Users/jerenolsen/Desktop/Exploring PGP Harvard/23andMe/PGP_HVD_23andMe_complete_profiles.txt'
    CG_profiles = '/Users/jerenolsen/Desktop/Exploring PGP Harvard/Complete Genomics/PGP_HVD_CG_complete_profiles.txt'
    VG_profiles = '/Users/jerenolsen/Desktop/Exploring PGP Harvard/Veritas Genetics/PGP_HVD_VG_complete_profiles.txt'
    
    _23andMe = get_txt_profiles(_23andMe_profiles)
    CG = get_txt_profiles(CG_profiles)
    VG = get_txt_profiles(VG_profiles)
    
    if provider_id == '23andMe':
        pass #Keep all profiles
    elif provider_id == 'CG':
        paths = [path for path in paths if path[-13:-5] not in _23andMe]
    elif provider_id == 'VG':
        paths = [path for path in paths if path[-13:-5] not in _23andMe]
        paths = [path for path in paths if path[-13:-5] not in CG]
    else:
        return None
    
    return paths

# %%
test_path = '/Users/jerenolsen/Desktop/Exploring PGP Harvard/Complete Genomics/all-data-by-profile/huCA017E/ehrs'

# %%
def read_and_update_tables(ehr_dir_path):
    for file in os.listdir(ehr_dir_path):
        process_table_type(ehr_dir_path, file)
        
    return None

def process_all_files(all_data_directory, provider_id):
    
    paths = get_filepaths(all_data_directory)
    paths = remove_intersecting_profiles(paths, provider_id)
    
    for path in paths:
        read_and_update_tables(path)
        
    all_tables = {'demo info': demo_info, 
                  'conditions': conditions, 
                  'medications':medications, 
                  'allergies': allergies, 
                  'procedures':procedures, 
                  'test results': test_results, 
                  'immunizations':immunizations}
        
    for key in all_tables.keys():
        table = all_tables[key]
        all_tables[key] = table.reset_index(drop = True)
        
    return all_tables

# %% [markdown]
# # Complete Genomics

# %%
demo_info = pd.DataFrame(columns=['Date of Birth', 'Gender', 'Weight', 'Height', 'Blood Type', 'Race'])
conditions = pd.DataFrame(columns = ['Name', 'Start Date', 'End Date'])
medications = pd.DataFrame(columns = ['Name', 'Dosage', 'Frequency', 'Start Date', 'End Date'])
allergies = pd.DataFrame(columns = ['Name', 'Reaction/Severity', 'Start Date', 'End Date'])
procedures = pd.DataFrame(columns = ['Name', 'Date'])
test_results = pd.DataFrame(columns = ['Name', 'Result', 'Date'])
immunizations = pd.DataFrame(columns = ['Name', 'Date'])

directory = '/Users/jerenolsen/Desktop/Exploring PGP Harvard/Complete Genomics/all-data-by-profile'
all_tables_CG = process_all_files(directory, provider_id = 'CG')
for key in all_tables_CG:
    print(f"Table {key.upper()}:\n {all_tables_CG[key]} \n ")
# Out:
# Table DEMO INFO:
#      profile_id              Date of Birth  Gender          Weight  \
# 0     hu26B551  1961-12-27 (61 years old)     NaN   155lbs (70kg)
# 1     hu70D651  1961-12-12 (61 years old)  Female   158lbs (72kg)
# 2     huDBF9DD  1970-11-08 (52 years old)     NaN  280lbs (127kg)
# 3     huA5BEB9                        NaN  Female             NaN
# 4     hu57A769  1973-06-06 (49 years old)    Male   115lbs (52kg)
# ..         ...                        ...     ...             ...
# 119   huA0E089  1942-11-22 (80 years old)  Female   139lbs (63kg)
# 120   hu602487  1945-08-09 (77 years old)  Female   117lbs (53kg)
# 121   huAFA81C  1986-11-23 (36 years old)     NaN   200lbs (91kg)
# 122   huA02824  1980-07-15 (42 years old)    Male   190lbs (86kg)
# 123   hu604D39  1958-01-19 (65 years old)    Male  245lbs (111kg)
#
#                Height Blood Type                       Race
# 0     5ft 7in (170cm)        NaN                        NaN
# 1     5ft 9in (175cm)         O+                      White
# 2                 NaN        NaN                        NaN
# 3                 NaN         O+                      White
# 4     5ft 3in (160cm)        NaN                      White
# ..                ...        ...                        ...
# 119   5ft 4in (162cm)         A+                      White
# 120   5ft 5in (165cm)         O+                      White
# 121   5ft 9in (175cm)        NaN                        NaN
# 122  5ft 11in (180cm)        NaN                      White
# 123   5ft 8in (172cm)        AB+  Black or African American
#
# [124 rows x 7 columns]
#
# Table CONDITIONS:
#      profile_id                                Name  Start Date    End Date
# 0     hu604D39                              ASTHMA  2007-11-01         NaN
# 1     huA02824              Ankylosing Spondylitis  2005-02-01         NaN
# 2     huAFA81C               Male pattern alopecia         NaN         NaN
# 3     hu602487                 Atrial Fibrillation  2010-12-28  2010-12-28
# 4     hu602487  Basal cell of skin - face and arms  1998-01-01         NaN
# ..         ...                                 ...         ...         ...
# 799   huDBF9DD                Recurrent depression  1986-11-01         NaN
# 800   huDBF9DD                    High Cholesterol  2011-03-01         NaN
# 801   huDBF9DD                 High blood pressure  2011-03-01         NaN
# 802   huDBF9DD                     diabetes type 2  2014-06-01         NaN
# 803   huDBF9DD                             Obesity         NaN         NaN
#
# [804 rows x 4 columns]
#
# Table MEDICATIONS:
#       profile_id                       Name                            Dosage  \
# 0      hu604D39              Advair Diskus  250-50 mcg/Dose Disk with Device
# 1      huA02824                 Etanercept        50 mg/mL (0.98 mL) Syringe
# 2      hu602487                        asa                            325 mg
# 3      hu602487          Calcium Carbonate         500 mg (1,250 mg) Capsule
# 4      hu602487              Climara Patch                          0.050 mg
# ...         ...                        ...                               ...
# 1099   huA5BEB9                  Periostat                               NaN
# 1100   huDBF9DD                  invokamet                               NaN
# 1101   huDBF9DD               Atorvastatin                               NaN
# 1102   huDBF9DD                 Lisinopril                               NaN
# 1103   hu26B551  Effexor 75 MG Oral Tablet                 75 Milligram (mg)
#
#                     Frequency           Start Date End Date
# 0     Take 1, 2 times per day  2007-11-01 (refill)      NaN
# 1     Take 1, 1 time per week           2007-11-01      NaN
# 2      Take 1, 1 time per day           2010-08-28      NaN
# 3     Take 1, every other day           1995-01-01      NaN
# 4             1 time per week           1995-01-01      NaN
# ...                       ...                  ...      ...
# 1099                      NaN           2002-01-01      NaN
# 1100                      2.0           2014-06-01      NaN
# 1101                      1.0           2011-03-01      NaN
# 1102                      NaN           2011-03-08      NaN
# 1103                Take 3, 1           2009-02-01      NaN
#
# [1104 rows x 6 columns]
#
# Table ALLERGIES:
#      profile_id                                              Name  \
# 0     huA02824                                       Penicillins
# 1     hu602487                                         chocolate
# 2     huA0E089  dogs, cat dander, pollen(I don't know what type)
# 3     huA0E089            dogs, cats, horses, pollen, dust mites
# 4     hu2C1D94                                No Known Allergies
# ..         ...                                               ...
# 144   hu5A063B                                              mold
# 145   hu49F623                                              None
# 146   huAC887E                                           Walnuts
# 147   huEBD467                                        Wasp Venom
# 148   huDBF9DD                                           Bananas
#
#                      Reaction/Severity  Start Date End Date
# 0                               Severe         NaN      NaN
# 1                                 MILD  2008-01-01      NaN
# 2                                 MILD  1944-01-01      NaN
# 3                                 MILD  1942-11-01      NaN
# 4                                 Mild         NaN      NaN
# ..                                 ...         ...      ...
# 144                              cough         NaN      NaN
# 145                               MILD         NaN      NaN
# 146                               MILD         NaN      NaN
# 147                             Severe         NaN      NaN
# 148  chest tightness and/or discomfort         NaN      NaN
#
# [149 rows x 5 columns]
#
# Table PROCEDURES:
#      profile_id                                               Name        Date
# 0     huA02824          Laser surgery on the eye for retinal hole         NaN
# 1     huA02824              Patent Ductus Arteriosus (PDA) Repair         NaN
# 2     huA02824                                  Strabismus Repair         NaN
# 3     hu602487                Salpingo-oophorectomy left (?) side  1994-12-01
# 4     hu602487  Salpingo-oophorectomy and Total Hysterectomy V...  1995-08-01
# ..         ...                                                ...         ...
# 604   hu26B551                             Extraction of cataract  2016-04-07
# 605   hu26B551                              Hearing aid provision  2016-04-07
# 606   hu26B551                                          Radiation  2006-05-20
# 607   hu26B551                           Intravenous chemotherapy  2006-01-20
# 608   hu26B551                               Lumpectomy of breast  2005-12-07
#
# [609 rows x 3 columns]
#
# Table TEST RESULTS:
#       profile_id             Name       Result        Date
# 0      hu604D39           Height    68 inches  2010-11-28
# 1      hu604D39      Hours slept      5 hours  2010-11-28
# 2      hu604D39           Weight       245 lb  2010-11-28
# 3      huA02824  HLA-B27 Antigen     Positive         NaN
# 4      huA02824           Height    71 inches  2009-08-06
# ...         ...              ...          ...         ...
# 3297   hu57A769           Weight  1792 ounces  2009-08-04
# 3298   hu57A769           Weight       105 lb  2010-10-15
# 3299   hu57A769           Weight       115 lb  2011-08-23
# 3300   hu70D651           Height    69 inches  2009-08-24
# 3301   hu70D651           Weight  2528 ounces  2009-08-24
#
# [3302 rows x 4 columns]
#
# Table IMMUNIZATIONS:
#      profile_id                                               Name        Date
# 0     huA02824       Hepatitis B Vaccine, Adolescent or Pediatric         NaN
# 1     huA02824                Measles/Mumps/Rubella (MMR) Vaccine         NaN
# 2     huA02824  Tetanus/Diphteria (Td) Toxoids, Older Children...         NaN
# 3     hu602487                Pneumococcal polysaccharide vaccine  2010-09-28
# 4     hu602487                 Pneumococcal Vaccine, Type Unknown  2010-09-28
# ..         ...                                                ...         ...
# 432   hu57A769  Tetanus/Diphteria (Td) Toxoids, Older Children...         NaN
# 433   huA5BEB9                 Pneumococcal Vaccine, Type Unknown  2002-01-01
# 434   huA5BEB9                                   Shingles Vaccine  2007-01-01
# 435   huA5BEB9                       Tetanus Toxoid, Unknown Type  2004-01-01
# 436   hu70D651                       Tetanus Toxoid, Unknown Type         NaN
#
# [437 rows x 3 columns]

# %%
#DEBUGGING
len(demo_info)
demo_info.head()
# Out:
#   profile_id              Date of Birth  Gender          Weight  \
# 0   hu882406  1970-10-28 (52 years old)    Male   152lbs (69kg)
# 0   huA939D6  1946-07-06 (76 years old)    Male   178lbs (81kg)
# 0   hu74C42F  1989-11-12 (33 years old)     NaN   204lbs (93kg)
# 0   huB0DE0F  1967-05-17 (55 years old)  Female  227lbs (103kg)
# 0   hu094BE5  1933-11-25 (89 years old)     NaN             NaN
#
#              Height Blood Type   Race
# 0   5ft 8in (172cm)         O+  White
# 0               NaN         A+  White
# 0  5ft 10in (177cm)        NaN    NaN
# 0   5ft 6in (167cm)         A-  White
# 0               NaN        NaN    NaN

# %% [markdown]
# ## Complete Genomics Conditions Counts

# %%
df1 = conditions['Name'].value_counts()
df1.head(20)
# Out:
# ASTHMA                                             13
# Allergies                                          11
# Myopia                                             11
# Sinusitis                                          10
# Bronchitis                                         10
# Pharyngitis                                        10
# Chickenpox                                          9
# DEPRESSION                                          9
# Streptococcal Pharyngitis                           9
# Hypertension                                        8
# Nearsightedness                                     8
# High Cholesterol                                    8
# Attention Deficit Hyperactivity Disorder (ADHD)     8
# Tonsillitis                                         7
# Glaucoma                                            7
# High blood pressure                                 7
# Hay fever                                           6
# Obesity                                             6
# Anxiety                                             6
# Astigmatism                                         6
# Name: Name, dtype: int64

# %% [markdown]
# ## Complete Genomics Cancer Occurences

# %%
df2 = conditions[conditions["Name"].str.contains('Cancer')]
df3 = conditions[conditions["Name"].str.contains('cancer')]
df4 = pd.concat([df2,df3])
df4.reset_index(drop=True, inplace=True)

# %%
df4.head(20)
# Out:
#   profile_id                    Name  Start Date    End Date
# 0   huBA30D4         Prostate Cancer         NaN         NaN
# 1   hu1E868D           Breast Cancer         NaN         NaN
# 2   hu52B7E5           Breast Cancer  2006-07-17         NaN
# 3   hu8073B9            Nasal Cancer  1999-09-15  2002-01-30
# 4   hu6E4515            Colon Cancer  2005-12-31  2010-02-18
# 5   hu61466C         Prostate Cancer  2009-11-15  2010-03-12
# 6   hu92C40A           Breast Cancer  2010-10-01         NaN
# 7   huB1FD55             Skin Cancer  2009-01-01  2009-01-01
# 8   hu687B6B      endometrial cancer  1987-10-27  1989-10-27
# 9   hu04FD18  Basal cell skin cancer  1995-01-01  1995-01-01

# %% [markdown]
# ## Complete Genomics Allergy Counts

# %%
df1 = allergies['Name'].value_counts()
df1.head(20)
# Out:
# Penicillins                       13
# House Dust                         5
# Pollen Extracts                    5
# pollen                             4
# Allergy to penicillin              3
# Mold Extracts                      3
# Cat Hair Std Extract               3
# Honey Bee Venom Protein            3
# Nothing                            2
# Cat/Feline Product Derivatives     2
# Cephalosporins                     2
# Sulfa (Sulfonamides)               2
# House dust allergy                 2
# mold                               2
# Grass Pollen-Kentucky Blu,Std      2
# Gluten                             2
# None                               2
# Canine Proteins                    2
# No Known Allergies                 2
# dust mites                         2
# Name: Name, dtype: int64

# %%
df1 = allergies['Name'].value_counts()
df1.head(20)
df1.iloc[0:5].plot.bar(ylabel = 'Occurences', title = 'CG Allergies', rot = 55)
# Out:
# <AxesSubplot:title={'center':'CG Allergies'}, ylabel='Occurences'>

# %% [markdown]
# # 23andMe

# %%
demo_info = pd.DataFrame(columns=['Date of Birth', 'Gender', 'Weight', 'Height', 'Blood Type', 'Race'])
conditions = pd.DataFrame(columns = ['Name', 'Start Date', 'End Date'])
medications = pd.DataFrame(columns = ['Name', 'Dosage', 'Frequency', 'Start Date', 'End Date'])
allergies = pd.DataFrame(columns = ['Name', 'Reaction/Severity', 'Start Date', 'End Date'])
procedures = pd.DataFrame(columns = ['Name', 'Date'])
test_results = pd.DataFrame(columns = ['Name', 'Result', 'Date'])
immunizations = pd.DataFrame(columns = ['Name', 'Date'])

directory = '/Users/jerenolsen/Desktop/Exploring PGP Harvard/23andMe/all-data-by-profile'
all_tables_23andMe = process_all_files(directory, provider_id = '23andMe')
for key in all_tables_23andMe:
    print(f"Table {key.upper()}:\n {all_tables_23andMe[key]} \n ")
# Out:
# Table DEMO INFO:
#      profile_id              Date of Birth  Gender          Weight  \
# 0     hu6ED94A  1950-08-05 (72 years old)    Male   128lbs (58kg)
# 1     hu1DD730  1990-09-23 (32 years old)     NaN   188lbs (85kg)
# 2     hu919BBA  1967-06-09 (55 years old)     NaN   185lbs (84kg)
# 3     hu016B28  1962-08-02 (60 years old)    Male  290lbs (132kg)
# 4     hu25E94B  1968-03-24 (54 years old)  Female             NaN
# ..         ...                        ...     ...             ...
# 306   huD0449C  1971-03-12 (51 years old)  Female   110lbs (50kg)
# 307   hu5A0DFE  1972-03-27 (50 years old)     NaN   185lbs (84kg)
# 308   huADA07D  1987-11-16 (35 years old)    Male   135lbs (61kg)
# 309   hu2FEC01  1985-10-06 (37 years old)     NaN   148lbs (67kg)
# 310   huF0B9DB  1972-08-13 (50 years old)     NaN  232lbs (105kg)
#
#                Height Blood Type                              Race
# 0     5ft 7in (170cm)         O+                             White
# 1     5ft 3in (160cm)        NaN                               NaN
# 2    5ft 11in (180cm)        NaN                               NaN
# 3     5ft 5in (165cm)         A+                             White
# 4                 NaN         O+  American Indian or Alaska Native
# ..                ...        ...                               ...
# 306   5ft 4in (162cm)        NaN                             White
# 307   5ft 6in (167cm)        NaN                               NaN
# 308   5ft 3in (160cm)         A+                   Hispanic/Latino
# 309   5ft 9in (175cm)        NaN                               NaN
# 310   5ft 7in (170cm)        NaN                               NaN
#
# [311 rows x 7 columns]
#
# Table CONDITIONS:
#       profile_id                                Name  Start Date    End Date
# 0      hu5A0DFE      Irritable Bowel Syndrome (IBS)         NaN         NaN
# 1      hu5A0DFE                         Acid reflux         NaN         NaN
# 2      huA33758                             Anxiety  1981-01-01         NaN
# 3      huA33758  Avascular Necrosis - Femoral Heads  2000-06-01  2002-04-01
# 4      huA33758                      Dermatographia  1980-01-01  1998-01-01
# ...         ...                                 ...         ...         ...
# 1805   hu1DD730                 Bipolar II disorder         NaN         NaN
# 1806   hu6ED94A                    High Cholesterol         NaN         NaN
# 1807   hu6ED94A                        Hypertension         NaN         NaN
# 1808   hu6ED94A                     Prostate Cancer  2011-05-01         NaN
# 1809   hu6ED94A                     Raynaud Disease         NaN         NaN
#
# [1810 rows x 4 columns]
#
# Table MEDICATIONS:
#       profile_id                                               Name  \
# 0      hu5A0DFE                                     Red Yeast Rice
# 1      hu5A0DFE                            DHA 200 MG Oral Capsule
# 2      hu5A0DFE                               FOCUS FACTOR CAP/TAB
# 3      hu5A0DFE               Bilberry extract 500 MG Oral Capsule
# 4      hu5A0DFE                                          Oxaprozin
# ...         ...                                                ...
# 3023   hu1DD730  bupropion hydrochloride 300 MILLIGRAM In 1 TAB...
# 3024   hu1DD730                                 lamotrigine 200 MG
# 3025   hu6ED94A                                          Cartia XT
# 3026   hu6ED94A                                         Lisinopril
# 3027   hu6ED94A                                        Simvastatin
#
#                   Dosage                Frequency  Start Date    End Date
# 0     600 Milligram (mg)      Take 1, twice daily         NaN         NaN
# 1     450 Milligram (mg)      Take 1, twice daily         NaN         NaN
# 2                    NaN    Take 2, 2 times daily  2011-07-25         NaN
# 3     500 Milligram (mg)    Take 1, 1 times daily  2011-07-20         NaN
# 4                 600 mg  Take 1, 2 times per day  2008-09-10  2008-10-10
# ...                  ...                      ...         ...         ...
# 3023  300 Milligram (mg)     Take 1, 1 time daily         NaN         NaN
# 3024                 NaN     Take 1, 1 time daily         NaN         NaN
# 3025                 NaN                      NaN         NaN         NaN
# 3026                 NaN                      NaN         NaN         NaN
# 3027                 NaN                      NaN         NaN         NaN
#
# [3028 rows x 6 columns]
#
# Table ALLERGIES:
#      profile_id                           Name  \
# 0     hu2FEC01                  Grass, Pollen
# 1     hu5A0DFE                     House Dust
# 2     hu5A0DFE  Grass Pollen-Kentucky Blu,Std
# 3     huD0449C                         pollen
# 4     huA33758             Poison Ivy Extract
# ..         ...                            ...
# 386   huD4F7DB                      Shellfish
# 387   huD85057                   Black Walnut
# 388   huD85057                  Mold Extracts
# 389   hu1DD730                Codeine allergy
# 390   hu1DD730                        Lanolin
#
#                    Reaction/Severity  Start Date End Date
# 0                                NaN  1993-01-01      NaN
# 1                                NaN         NaN      NaN
# 2                                NaN         NaN      NaN
# 3                               MILD         NaN      NaN
# 4                               MILD  1975-01-01      NaN
# ..                               ...         ...      ...
# 386                           SEVERE  1976-01-01      NaN
# 387                             Mild         NaN      NaN
# 388                             Mild         NaN      NaN
# 389  itching or numbness or tingling         NaN      NaN
# 390  itching or numbness or tingling         NaN      NaN
#
# [391 rows x 5 columns]
#
# Table PROCEDURES:
#       profile_id                                   Name        Date
# 0      hu5A0DFE                           Appendectomy  1981-02-04
# 1      huAEADC0                             Cystoscopy         NaN
# 2      huAEADC0                 sebaceous cyst removal         NaN
# 3      huAEADC0                              Vasectomy         NaN
# 4      huAEADC0                             Urinalysis  2006-10-19
# ...         ...                                    ...         ...
# 1489   hu1DD730                          Tonsillectomy  2016-07-25
# 1490   hu1DD730               Bilateral tubal ligation  2016-03-21
# 1491   hu1DD730    Laparoscopic emergency appendectomy  2013-01-08
# 1492   hu6ED94A  MRA Brain - With and Without Contrast  2006-06-01
# 1493   hu6ED94A                            Colonoscopy  2008-05-01
#
# [1494 rows x 3 columns]
#
# Table TEST RESULTS:
#        profile_id                             Name       Result        Date
# 0       huF0B9DB                         Cortisol    7.7 ug/dL         NaN
# 1       huF0B9DB                              TSH   1.9 uIU/mL         NaN
# 2       huF0B9DB                        Prolactin     10 ng/mL         NaN
# 3       huF0B9DB                       Hematocrit         53 %         NaN
# 4       huF0B9DB               Cholesterol, Total    220 mg/dL         NaN
# ...          ...                              ...          ...         ...
# 15541   hu6ED94A                  HDL Cholesterol           57  2009-05-05
# 15542   hu6ED94A  Prostate-specific Antigen (PSA)          4.2  2009-05-05
# 15543   hu6ED94A                  LDL Cholesterol           67  2009-05-05
# 15544   hu6ED94A                           Height    67 inches  2010-04-16
# 15545   hu6ED94A                           Weight  2048 ounces  2010-04-16
#
# [15546 rows x 4 columns]
#
# Table IMMUNIZATIONS:
#       profile_id                                         Name        Date
# 0      huADA07D                  DTP/Hib/Hepatitis B Vaccine         NaN
# 1      huADA07D                   Hepatitis A Vaccine, Adult         NaN
# 2      huADA07D          Measles/Mumps/Rubella (MMR) Vaccine         NaN
# 3      huADA07D          Meningococcal Vaccine, Type Unknown         NaN
# 4      huADA07D  Tetanus/Diphtheria/Pertussis (Tdap) Vaccine         NaN
# ...         ...                                          ...         ...
# 1094   hu1DD730             Hepatitis B vaccine (HepB) Child         NaN
# 1095   hu1DD730        Measles, mumps, rubella vaccine (MMR)         NaN
# 1096   hu1DD730           Human papillomavirus vaccine (HPV)         NaN
# 1097   hu1DD730                                 TdaP booster  2012-01-23
# 1098   hu6ED94A                 Tetanus Toxoid, Unknown Type  2007-03-01
#
# [1099 rows x 3 columns]

# %% [markdown]
# ## 23andMe EHR Conditions Occurences

# %%
df1 = conditions['Name'].value_counts()
df1.head(20)
# Out:
# ASTHMA                                             30
# High Cholesterol                                   22
# DEPRESSION                                         20
# Nearsightedness                                    20
# Astigmatism                                        18
# Hypothyroidism                                     18
# CYSTOID MACULAR DEGENERATION                       18
# Hypertension                                       14
# Myopia                                             13
# High blood pressure                                12
# Anxiety                                            12
# Chickenpox                                         12
# Sleep Apnea                                        12
# Attention Deficit Hyperactivity Disorder (ADHD)    11
# Gastroesophageal Reflux Disease (GERD)             11
# Acid reflux                                        10
# HYPERCHOLESTEROLEMIA                               10
# Kidney stones                                      10
# Major Depression                                    9
# Allergies                                           9
# Name: Name, dtype: int64

# %%
df_diab = conditions[conditions['Name'].str.contains('diab') == True]
df_diab.head()
# Out:
#    profile_id             Name Start Date End Date
# 3    huAF469C  diabetes type 2        NaN      NaN
# 10   hu30888B      Prediabetes        NaN      NaN

# %% [markdown]
# ## 23andME EHR Cancer Occurences

# %%
df2 = conditions[conditions["Name"].str.contains('Cancer')]
df3 = conditions[conditions["Name"].str.contains('cancer')]
df4 = pd.concat([df2,df3])
df4.reset_index(drop=True, inplace=True)

# %%
df4.head(20)
# Out:
#   profile_id                                               Name  Start Date  \
# 0   hu868880                                      Kidney Cancer         NaN
# 1   hu4CFB79                                      Breast Cancer  2009-01-01
# 2   hu524B5B                                      Breast Cancer  2004-03-23
# 3   hu56B3B6                                        Skin Cancer         NaN
# 4   hu14262A                           Skin Cancer (Basal Cell)  2010-01-01
# 5   huD889CC                                    Prostate Cancer         NaN
# 6   hu6ED94A                                    Prostate Cancer  2011-05-01
# 7   hu9CEB09  Removal of ovary and borderline ovarian cancer...  2001-04-13
# 8   hu56B3B6                             Basal cell skin cancer  2011-02-16
# 9   hu56B3B6                             Basal cell skin cancer         NaN
#
#      End Date
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7  2001-06-22
# 8  2011-08-24
# 9         NaN

# %% [markdown]
# ## 23andMe EHR Allergy Counts

# %%
df1 = allergies['Name'].value_counts()
df1.head(20)
df1.iloc[0:5].plot.bar(ylabel = 'Occurences', title = '23andMe Allergies', rot = 55)
# Out:
# <AxesSubplot:title={'center':'23andMe Allergies'}, ylabel='Occurences'>

# %% [markdown]
# ## 23andMe Test Results

# %%
df1 = test_results
df1 = df1[df1.Name.str.contains('eight') == False]
df1 = df1[df1.Name.str.contains('Fat Mass') == False]
df1 = df1[df1.Name.str.contains('Calor') == False]
unique = df1['profile_id'].value_counts()
#df1 = test_results[test_results['Name'].str.contains('Weight') == False]
#f1 = test_results[test_results['Name'].str.contains('Fat Mass') == False]
unique
# Out:
# hu96713F    2771
# huD57BBF    1305
# hu7A2F1D     489
# huEDF7DA     461
# huF9E138     271
#             ...
# hu024B5D       1
# hu9AE5EE       1
# hu4F8813       1
# hu939B7C       1
# hu2D53F2       1
# Name: profile_id, Length: 151, dtype: int64

# %% [markdown]
# ## 23andMe Procedures

# %%
df1 = procedures
unique = df1['Name'].value_counts()
unique
# Out:
# PROFF SERVICES FOR ALLERGEN IMMUNOTHERAPY MULTI INJECT    69
# Appendectomy                                              21
# Therapeutic exercise                                      20
# Tonsillectomy                                             20
# Procedure S8838                                           19
#                                                           ..
# Uterine Ablation                                           1
# Excision of a Basal Cell                                   1
# Excision of a skin cancer - Basal Cell                     1
# Replacement of a cataract with intraocular lens            1
# MRA Brain - With and Without Contrast                      1
# Name: Name, Length: 679, dtype: int64

# %% [markdown]
# # Veritas Genetics

# %%
demo_info = pd.DataFrame(columns=['Date of Birth', 'Gender', 'Weight', 'Height', 'Blood Type', 'Race'])
conditions = pd.DataFrame(columns = ['Name', 'Start Date', 'End Date'])
medications = pd.DataFrame(columns = ['Name', 'Dosage', 'Frequency', 'Start Date', 'End Date'])
allergies = pd.DataFrame(columns = ['Name', 'Reaction/Severity', 'Start Date', 'End Date'])
procedures = pd.DataFrame(columns = ['Name', 'Date'])
test_results = pd.DataFrame(columns = ['Name', 'Result', 'Date'])
immunizations = pd.DataFrame(columns = ['Name', 'Date'])

directory = '/Users/jerenolsen/Desktop/Exploring PGP Harvard/Veritas Genetics/all-data-by-profile'
all_tables_CG = process_all_files(directory, provider_id = 'VG')
for key in all_tables_CG:
    print(f"Table {key.upper()}:\n {all_tables_CG[key]} \n ")
# Out:
# Table DEMO INFO:
#     profile_id              Date of Birth  Gender          Weight  \
# 0    hu882406  1970-10-28 (52 years old)    Male   152lbs (69kg)
# 1    huA939D6  1946-07-06 (76 years old)    Male   178lbs (81kg)
# 2    hu74C42F  1989-11-12 (33 years old)     NaN   204lbs (93kg)
# 3    huB0DE0F  1967-05-17 (55 years old)  Female  227lbs (103kg)
# 4    hu094BE5  1933-11-25 (89 years old)     NaN             NaN
# 5    hu5E3021  1956-10-20 (66 years old)     NaN   122lbs (55kg)
# 6    hu4A9989  1980-08-07 (42 years old)     NaN   167lbs (76kg)
# 7    huE5A9A3  1953-01-01 (70 years old)     NaN   215lbs (98kg)
# 8    hu1FD496  1959-06-23 (63 years old)    Male   180lbs (82kg)
# 9    hu6A8D30                        NaN     NaN   137lbs (62kg)
# 10   huCF305F  1942-10-11 (80 years old)    Male   139lbs (63kg)
# 11   hu63165B  1959-01-30 (64 years old)    Male   160lbs (73kg)
# 12   hu2C27FF  1981-03-02 (42 years old)     NaN  325lbs (147kg)
# 13   hu6E004A  1963-09-19 (59 years old)     NaN   165lbs (75kg)
# 14   hu5CA617  1943-12-31 (79 years old)     NaN   207lbs (94kg)
# 15   huA2F4B9  1944-06-29 (78 years old)    Male   180lbs (82kg)
# 16   hu4B102F  1992-11-07 (30 years old)     NaN   135lbs (61kg)
#
#               Height Blood Type   Race
# 0    5ft 8in (172cm)         O+  White
# 1                NaN         A+  White
# 2   5ft 10in (177cm)        NaN    NaN
# 3    5ft 6in (167cm)         A-  White
# 4                NaN        NaN    NaN
# 5    5ft 9in (175cm)        NaN    NaN
# 6        6ft (182cm)        NaN    NaN
# 7    6ft 1in (185cm)        NaN    NaN
# 8        6ft (182cm)        NaN  White
# 9                NaN        NaN    NaN
# 10   5ft 7in (170cm)         A-  White
# 11   6ft 2in (187cm)         O+  White
# 12       6ft (182cm)        NaN    NaN
# 13   5ft 8in (172cm)        NaN    NaN
# 14               NaN        NaN    NaN
# 15   6ft 1in (185cm)         O+  White
# 16   5ft 7in (170cm)        NaN    NaN
#
# Table CONDITIONS:
#      profile_id                     Name  Start Date    End Date
# 0     hu4B102F              Sleep Apnea  2012-03-01  2013-08-01
# 1     hu4B102F               Concussion  2011-12-10  2013-05-01
# 2     hu4B102F  Exercise-induced asthma  1999-05-01         NaN
# 3     hu4B102F    Seborrheic Dermatitis  1999-05-01         NaN
# 4     huA2F4B9                Allergies         NaN         NaN
# ..         ...                      ...         ...         ...
# 99    huB0DE0F           Hypothyroidism  2000-04-04         NaN
# 100   huA939D6         L4-5 laminectomy  1969-01-01         NaN
# 101   hu882406         High Cholesterol  1986-01-01         NaN
# 102   hu882406                    Hives  2005-01-01         NaN
# 103   hu882406               Stuttering  1990-01-01         NaN
#
# [104 rows x 4 columns]
#
# Table MEDICATIONS:
#      profile_id                                           Name  \
# 0     hu4B102F  CLOBETASOL PROPIONATE 0.5 MG TOPICAL SOLUTION
# 1     hu4B102F                                           Apri
# 2     hu4B102F                                      Albuterol
# 3     huA2F4B9                                   Fexofenadine
# 4     huA2F4B9                          Fexofenadine Hcl Tabs
# ..         ...                                            ...
# 149   huA939D6                                     Lovastatin
# 150   hu882406                                     Loratadine
# 151   hu882406                            Omega-3 Fatty Acids
# 152   hu882406                                    resveratrol
# 153   hu882406                                    Simvastatin
#
#                Dosage                Frequency  Start Date End Date
# 0    0.05 Percent (%)             twice a week         NaN      NaN
# 1                 NaN               once daily         NaN      NaN
# 2                 NaN          before exercise         NaN      NaN
# 3                 NaN                      NaN         NaN      NaN
# 4               180MG                      NaN         NaN      NaN
# ..                ...                      ...         ...      ...
# 149      20 mg Tablet   Take 1, 1 time per day  1998-12-01      NaN
# 150              10mg  Take 1, every other day         NaN      NaN
# 151  1,000 mg Capsule   Take 1, 1 time per day         NaN      NaN
# 152             500mg   Take 1, 1 time per day         NaN      NaN
# 153      40 mg Tablet   Take 1, 1 time per day         NaN      NaN
#
# [154 rows x 6 columns]
#
# Table ALLERGIES:
#     profile_id                              Name  \
# 0    hu4B102F  Multiple environmental allergies
# 1    hu4B102F                    animal allergy
# 2    hu4B102F                  Seasonal allergy
# 3    hu5CA617                        IV Demerol
# 4    hu5CA617                      contrast dye
# 5    hu5CA617             Allergy to penicillin
# 6    hu5CA617                        Bee Stings
# 7    hu6E004A                         Oxycodone
# 8    hu63165B                        cat dander
# 9    hu63165B                           grasses
# 10   hu63165B                             molds
# 11   hu63165B                    mountain cedar
# 12   hu63165B                       tree pollen
# 13   huCF305F                         Lidocaine
# 14   hu74C42F                               Dog
# 15   huA939D6                       Penicillins
# 16   huA939D6                           Ragweed
#
#                    Reaction/Severity  Start Date    End Date
# 0                           sneezing         NaN         NaN
# 1                           sneezing         NaN         NaN
# 2                           sneezing         NaN         NaN
# 3                                NaN  1993-04-30         NaN
# 4                 anaphylactic shock  1979-02-21         NaN
# 5   hives (red, raised, itchy bumps)  1969-03-12         NaN
# 6                           swelling  1967-08-31         NaN
# 7             nausea and/or vomiting  2003-09-15         NaN
# 8                               MILD         NaN         NaN
# 9                               MILD         NaN         NaN
# 10                              MILD         NaN         NaN
# 11                              MILD         NaN         NaN
# 12                              MILD         NaN         NaN
# 13                              Mild         NaN         NaN
# 14                          sneezing         NaN         NaN
# 15                              MILD  1952-01-01         NaN
# 16                              MILD  1956-07-06  1980-08-01
#
# Table PROCEDURES:
#     profile_id                                               Name        Date
# 0    hu4B102F                    Tonsillectomy and adenoidectomy  2013-08-01
# 1    huA2F4B9                                  Abdominal CT Scan         NaN
# 2    huA2F4B9                               Shoulder arthroscopy         NaN
# 3    huA2F4B9                                      Sigmoidoscopy         NaN
# 4    huA2F4B9                                          Vasectomy         NaN
# 5    hu2C27FF                                      Adenoidectomy         NaN
# 6    hu63165B                            CT Sinus - Coronal Only         NaN
# 7    hu63165B                           epiderma cysts excisions  2004-03-22
# 8    hu63165B  Colonoscopy - Flexible, With Tumor Or Polyp Re...  2006-06-01
# 9    hu63165B        Procedure for prolapse or hemorrhoids (PPH)  2006-09-12
# 10   huCF305F                                       Appendectomy         NaN
# 11   huCF305F                                       Circumcision         NaN
# 12   huCF305F                                        Colonoscopy         NaN
# 13   huCF305F                                      Tonsillectomy         NaN
# 14   huCF305F                     Compound fractures both femurs         NaN
# 15   huCF305F                   Crushed left testicle motorcycle  1964-05-10
# 16   huE5A9A3                                        Colonoscopy  2013-10-07
# 17   huE5A9A3                                        Colonoscopy  2013-10-07
# 18   huE5A9A3                                        ECG 12-LEAD  2012-05-11
# 19   huE5A9A3               TRANSTHORACIC ECHOCARDIOGRAM - ADULT  2010-04-17
# 20   huE5A9A3                                        ECG 12-LEAD  2010-04-16
# 21   huE5A9A3                                        ECG 12-LEAD  2010-04-16
# 22   huE5A9A3         LAMINECTOMY SPINE LUMBAR POSTERIOR 1 LEVEL  2010-04-07
# 23   huE5A9A3  ECG 12-LEAD (PERFORMED IN PREADMISSION UNIT ONLY)  2010-03-24
# 24   huB0DE0F                               wisdom teeth removed  1993-04-01
# 25   hu882406                                       Appendectomy  2009-01-05
#
# Table TEST RESULTS:
#      profile_id                      Name       Result        Date
# 0     huA2F4B9                    Height    73 inches  2009-08-04
# 1     huA2F4B9                    Weight  2880 ounces  2009-08-04
# 2     hu2C27FF                    Weight       325 lb  2011-11-15
# 3     hu2C27FF                  Fat Mass     118.7 lb  2011-11-15
# 4     hu2C27FF                  Fat Mass     115.8 lb  2011-11-07
# ..         ...                       ...          ...         ...
# 454   huA939D6  Diastolic Blood Pressure      78 mmHg  2010-11-22
# 455   hu882406        Cholesterol, Total    200 Mg/dL  2011-06-17
# 456   hu882406        Cholesterol, Total    122 Mg/dL  2011-07-31
# 457   hu882406                    Height        68 in  2011-08-07
# 458   hu882406                    Weight       152 lb  2011-08-07
#
# [459 rows x 4 columns]
#
# Table IMMUNIZATIONS:
#     profile_id                                               Name        Date
# 0    huA2F4B9                                Current Flue / H1N1  2010-10-01
# 1    hu63165B         Diphtheria/Tetanus/Pertussis (DTP) Vaccine         NaN
# 2    hu63165B                                           Flu Shot         NaN
# 3    hu63165B                                   H1N1 (swine flu)  2009-12-17
# 4    hu63165B                         Hepatitis A Vaccine, Adult         NaN
# 5    hu63165B                         Hepatitis B Vaccine, Adult         NaN
# 6    hu63165B                    Influenza Vaccine, Type Unknown         NaN
# 7    hu63165B                                    Measles Vaccine         NaN
# 8    hu63165B                Measles/Mumps/Rubella (MMR) Vaccine         NaN
# 9    hu63165B                 Pneumococcal Vaccine, Type Unknown         NaN
# 10   hu63165B              Poliovirus vaccine, inactivated (IPV)         NaN
# 11   hu63165B               Poliovirus Vaccine, Live, Oral (OPV)         NaN
# 12   hu63165B                    Rotavirus Vaccine, Type Unknown         NaN
# 13   hu63165B                        Smallpox (Vaccinia) Vaccine         NaN
# 14   hu63165B  Tetanus/Diphteria (Td) Toxoids, Older Children...         NaN
# 15   hu63165B        Tetanus/Diphtheria/Pertussis (Tdap) Vaccine         NaN
# 16   hu63165B                      Typhoid Vaccine, Unknown Type         NaN
# 17   hu63165B                                  Varicella Vaccine         NaN
# 18   huCF305F                   Poliovirus Vaccine, Type Unknown         NaN
# 19   huCF305F                        Smallpox (Vaccinia) Vaccine         NaN
# 20   huCF305F  Tetanus/Diphteria (Td) Toxoids, Older Children...         NaN
# 21   huCF305F                      Typhoid Vaccine, Unknown Type         NaN
# 22   hu6A8D30                                  Pneumovax Prevlar  2014-07-11
# 23   hu6A8D30                               Pneumococcal vaccine  2013-08-08
# 24   hu6A8D30                   Hepatitis B vaccine (HepB) Adult  2012-08-28
# 25   huE5A9A3                       INFLUENZA VACCINE IM (ADMIN)  2016-09-26
# 26   huE5A9A3                       INFLUENZA VACCINE IM (ADMIN)  2015-10-02
# 27   huE5A9A3                                            Unknown  2014-10-28
# 28   huE5A9A3  TETANUS TOXOID/DIPHTHERIA TOXOID/ACELLULAR PER...  2014-08-23
# 29   huE5A9A3                       INFLUENZA VACCINE IM (ADMIN)  2013-10-18
# 30   huE5A9A3         ZOSTAVAX (VARICELLA ZOSTER VACCINE (ADMIN)  2013-07-31
# 31   huE5A9A3                       INFLUENZA VACCINE IM (ADMIN)  2012-11-02
# 32   huE5A9A3                                          Pneumovax  2012-05-11
# 33   huE5A9A3                    INFLUENZA VIRUS VACCINE (ADMIN)  2010-10-08
# 34   huE5A9A3                    INFLUENZA VIRUS VACCINE (ADMIN)  2009-09-15
# 35   huE5A9A3  DIPTH,PERTUSSIS-ACEL,TETANUS (ADACEL) >11 YRS ...  2009-06-04
# 36   huE5A9A3  DIPTHERIA & TETANUS TOXOID,ADSORBED, (DECAVAC/...  2004-12-15
# 37   hu4A9989                               Tetanus vaccine (TT)  2011-05-20
# 38   huB0DE0F                         BCG (Tuberculosis) Vaccine         NaN
# 39   huB0DE0F                                 Chickenpox Vaccine         NaN
# 40   huB0DE0F                         Hepatitis B Vaccine, Adult         NaN
# 41   huB0DE0F                                    Measles Vaccine         NaN
# 42   huB0DE0F                                      Mumps Vaccine         NaN
# 43   huB0DE0F                   Poliovirus Vaccine, Type Unknown         NaN
# 44   huB0DE0F                      Rho(D) immune globulin (RhIG)         NaN
# 45   huB0DE0F                        Smallpox (Vaccinia) Vaccine         NaN
# 46   huB0DE0F        Tetanus/Diphtheria/Pertussis (Tdap) Vaccine         NaN

# %%
df1 = conditions['Name'].value_counts()
df1.head(20)
# Out:
# Sinusitis, chronic                    3
# Sleep Apnea                           2
# Concussion                            2
# Hemorrhoids                           2
# Hernia, Abdominal                     2
# High Cholesterol                      2
# Epididymitis                          2
# Tonsillitis                           2
# gerd                                  2
# Hypothyroidism                        2
# Seborrheic Dermatitis                 2
# alchoholic, non-drinking              2
# chlamydosis avian                     2
# Hepatitis B Core Antibody Positive    1
# Geographic tongue                     1
# Gonorrhea                             1
# Phlebitis                             1
# Peripheral Neuropathy                 1
# Osteoarthritis                        1
# Nevi                                  1
# Name: Name, dtype: int64

# %%
df2 = conditions[conditions["Name"].str.contains('Cancer')]
df3 = conditions[conditions["Name"].str.contains('cancer')]
df4 = pd.concat([df2,df3])
df4.reset_index(drop=True, inplace=True)

# %%
df4.head(20)
# Out:
# Empty DataFrame
# Columns: [profile_id, Name, Start Date, End Date]
# Index: []

# %%
df1 = allergies['Name'].value_counts()
df1.head(20)
# Out:
# Multiple environmental allergies    1
# grasses                             1
# Penicillins                         1
# Dog                                 1
# Lidocaine                           1
# tree pollen                         1
# mountain cedar                      1
# molds                               1
# cat dander                          1
# animal allergy                      1
# Oxycodone                           1
# Bee Stings                          1
# Allergy to penicillin               1
# contrast dye                        1
# IV Demerol                          1
# Seasonal allergy                    1
# Ragweed                             1
# Name: Name, dtype: int64
